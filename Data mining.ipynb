# %% [markdown]
# # **Cài đặt và Import các thư viện cần thiết**

# %%
# !pip install seaborn
# !pip install pca
# !pip install kaleido
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import pca

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Import file dữ liệu từ file csv**

# %%
path_data = '/content/drive/MyDrive'
df = pd.read_csv(f'{path_data}/USvideos.csv', header=0, index_col=0) #đọc file csv
df.head(10) #đọc 20 dòng dữ liệu đầu tiên
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# gHZ1Qz0KiKM      17.14.11                              2 Weeks with iPhone X
# 39idVpFF7NQ      17.14.11          Roy Moore & Jeff Sessions Cold Open - SNL
# nc99ccSXST0      17.14.11                5 Ice Cream Gadgets put to the Test
# jr9QtXwC9vc      17.14.11  The Greatest Showman | Official Trailer 2 [HD]...
# TUmyygCMMGA      17.14.11  Why the rise of the robots won’t mean the end ...
#
#                      channel_title  category_id              publish_time  \
# video_id
# ...

# %%
#chi tiết của dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40949 entries, 2kyS6SvSYSE to ooyjaVdt-jA
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   trending_date           40949 non-null  object
#  1   title                   40949 non-null  object
#  2   channel_title           40949 non-null  object
#  3   category_id             40949 non-null  int64
#  4   publish_time            40949 non-null  object
#  5   tags                    40949 non-null  object
#  6   views                   40949 non-null  int64
#  7   likes                   40949 non-null  int64
#  8   dislikes                40949 non-null  int64
#  9   comment_count           40949 non-null  int64
#  10  thumbnail_link          40949 non-null  object
#  11  comments_disabled       40949 non-null  bool
#  12  ratings_disabled        40949 non-null  bool
#  13  video_error_or_removed  40949 non-null  bool
# ...

# %% [markdown]
# # **Loại bỏ thông tin không cần thiết**

# %%
#Loại bỏ thông tin không cần thiết theo columns
#Xài hàm drop 
df = df.drop("thumbnail_link", axis='columns')
df = df.drop("tags", axis='columns')
df = df.drop("ratings_disabled", axis='columns')
df = df.drop("video_error_or_removed", axis='columns')
df = df.drop("comments_disabled", axis='columns')
df = df.drop("channel_title", axis='columns')
df.head()
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
#
#              category_id              publish_time    views   likes  dislikes  \
# video_id
# 2kyS6SvSYSE           22  2017-11-13T17:13:01.000Z   748374   57527      2966
# 1ZAPwfrtAFY           24  2017-11-13T07:30:00.000Z  2418783   97185      6146
# 5qpjK5DgCt4           23  2017-11-12T19:05:24.000Z  3191434  146033      5339
# puqaWrEC7tY           24  2017-11-13T11:00:04.000Z   343168   10172       666
# d380meD0W0M           24  2017-11-12T18:01:41.000Z  2095731  132235      1989
#
# ...

# %% [markdown]
# # **Xử lý dữ liệu bị thiếu**

# %%
# Ta thêm hàm sum() để tổng lại số cột bị null trong data frame
# Thiếu 570 dòng dữ liệu ở description
df.isnull().sum()
# Out:
# trending_date      0
# title              0
# category_id        0
# publish_time       0
# views              0
# likes              0
# dislikes           0
# comment_count      0
# description      570
# dtype: int64

# %%
#Xài hàm dropna mặc định axis = 0 là xóa tất cả các dòng bị thiếu một vài thuộc tính
df = df.dropna()
df.head()
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
#
#              category_id              publish_time    views   likes  dislikes  \
# video_id
# 2kyS6SvSYSE           22  2017-11-13T17:13:01.000Z   748374   57527      2966
# 1ZAPwfrtAFY           24  2017-11-13T07:30:00.000Z  2418783   97185      6146
# 5qpjK5DgCt4           23  2017-11-12T19:05:24.000Z  3191434  146033      5339
# puqaWrEC7tY           24  2017-11-13T11:00:04.000Z   343168   10172       666
# d380meD0W0M           24  2017-11-12T18:01:41.000Z  2095731  132235      1989
#
# ...

# %%
#Kiểm tra tất cả dữ liệu đã hết null
df.isnull().sum()
# Out:
# trending_date    0
# title            0
# category_id      0
# publish_time     0
# views            0
# likes            0
# dislikes         0
# comment_count    0
# description      0
# dtype: int64

# %% [markdown]
# # **Kiểm tra các dữ liệu trùng nhau**

# %%
#Kiểm tra các dữ liệu trùng nhau
#Có 47 dòng dữ liệu trùng nhau
Dup_Rows = df[df.duplicated()]
Dup_Rows.count()
# Out:
# trending_date    47
# title            47
# category_id      47
# publish_time     47
# views            47
# likes            47
# dislikes         47
# comment_count    47
# description      47
# dtype: int64

# %%
#Có 47 dòng dữ liệu trùng ngày lên trending
Dup_Rows.head(47)
# Out:
#             trending_date                                              title  \
# video_id
# QBL8IRJ5yHU      18.15.05  Why I'm So Scared (being myself and crying too...
# t4pRQ0jn23Q      18.15.05  YoungBoy Never Broke Again Goes Sneaker Shoppi...
# j4KvrAUjn6c      18.15.05         WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# MAjY8mCTXWk      18.15.05  周杰倫 Jay Chou【不愛我就拉倒 If You Don't Love Me, It's...
# xhs8tf1v__w      18.15.05  Terry Crews Answers the Web's Most Searched Qu...
# E21NATEP9QI      18.15.05        Why Stradivarius violins are worth millions
# jzLlsbdrwQk      18.15.05                           $17 Pet vs. $100,000 Pet
# 1RZYOeQeIXE      18.15.05   Sarah Paulson Gets Scared During '5 Second Rule'
# WF82ABLw8s4      18.15.05  Gabby Barrett Sings I Have Nothing by Whitney ...
# r-3iathMo7o      18.15.05               The ULTIMATE $30,000 Gaming PC Setup
# NBSAQenU2Bk      18.15.05  Rooster Teeth Animated Adventures - Millie So ...
# ...

# %%
#Xử lí dữ liệu trùng
#Dữ liệu dòng dữ liệu trùng đầu tiên
df_count = df.count()
DF_RM_DUP = df.drop_duplicates(keep='first')
df_count_remove_duplicate = DF_RM_DUP.count()

print(f"Số dòng Dataframe trước loại bỏ Duplicate: {df_count}\n Số dòng Dataframe sau loại bỏ Duplicate: {df_count_remove_duplicate}")
# Out:
# Số dòng Dataframe trước loại bỏ Duplicate: trending_date    40379
# title            40379
# category_id      40379
# publish_time     40379
# views            40379
# likes            40379
# dislikes         40379
# comment_count    40379
# description      40379
# dtype: int64
#  Số dòng Dataframe sau loại bỏ Duplicate: trending_date    40332
# title            40332
# category_id      40332
# publish_time     40332
# views            40332
# likes            40332
# dislikes         40332
# comment_count    40332
# description      40332
# dtype: int64

# %% [markdown]
# # **Xử lý dữ liệu ngoại lai**

# %%
import plotly.express as px
import plotly.io as pio
"""
  Chia ra 20 cột (Cột đầu tiên từ 0 - 20M views có 40k videos)
  nbins = 20 tương ứng 20 triệu views trong 1 cột
  Thấy dữ liệu nhỏ lẻ trên 40 000 000
"""
fig = px.histogram(df,x="views", nbins=20) 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
"""
  Xoá toàn bộ hàng có views từ >= 40.000.000
  Đặt nbins = 20 tương ứng giá trị  2 triệu views 1 cột
"""
df = df.drop(df[df.views >=40000000].index)
fig = px.histogram(df,x="views", nbins=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
"""
  Đặt nbins = 20 tương ứng giá trị  200.000 likes 1 cột
"""
fig = px.histogram(df,x="likes",nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Xoá toàn bộ cột likes có giá trị ngoại lai lớn hơn 400 000
#Tương ứng 1 cột có 20.000 likes
df = df.drop(df[df.likes >=400000].index)
fig = px.histogram(df,x="likes", nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
#Tương ứng 1 cột có 20.000 dislikes
fig = px.histogram(df,x="dislikes", nbins=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Xoá toàn bộ cột likes có giá trị ngoại lai lớn hơn 39000
df = df.drop(df[df.dislikes >=39000].index)
fig = px.histogram(df,x="dislikes", nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Xử lý dữ liệu nhiễu bằng phương pháp bining data**

# %%
df['views'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
maxrange = int(np.ceil(max(df['views'])))
minrange = int(np.floor(min(df['views'])))
ageRange = maxrange - minrange
bins = 10
#Số cột tối đa để group by dữ liệu
binwidth = int(np.round(ageRange/bins))

# %%
print('max range is', maxrange)
print('min range is', minrange)
print('age range is', ageRange)
print('bin width is', binwidth)
# Out:
# max range is 29075706
# min range is 549
# age range is 29075157
# bin width is 2907516

# %%
intervals = [ views for views in range(minrange, maxrange + binwidth, binwidth)]
intervals
# Out:
# [549,
#  2908065,
#  5815581,
#  8723097,
#  11630613,
#  14538129,
#  17445645,
#  20353161,
#  23260677,
#  26168193,
#  29075709]

# %%
binlabels = ["bin" + str(i) for i in range (1, int(len(intervals)))]
binlabels
# Out:
# ['bin1',
#  'bin2',
#  'bin3',
#  'bin4',
#  'bin5',
#  'bin6',
#  'bin7',
#  'bin8',
#  'bin9',
#  'bin10']

# %%
df['Views_Cut'] = pd.cut(df['views'], bins = intervals, labels = None, include_lowest=True)

# %%
df['Views_Cut']
# Out:
# video_id
# 2kyS6SvSYSE      (548.999, 2908065.0]
# 1ZAPwfrtAFY      (548.999, 2908065.0]
# 5qpjK5DgCt4    (2908065.0, 5815581.0]
# puqaWrEC7tY      (548.999, 2908065.0]
# d380meD0W0M      (548.999, 2908065.0]
#                         ...
# _QWZvU7VCn8    (2908065.0, 5815581.0]
# 7UoP9ABJXGE    (2908065.0, 5815581.0]
# BZt0qjTWNhw      (548.999, 2908065.0]
# D6Oy4LfoqsU      (548.999, 2908065.0]
# oV0zkMe1K8s    (2908065.0, 5815581.0]
# Name: Views_Cut, Length: 38467, dtype: category
# Categories (10, interval[float64, right]): [(548.999, 2908065.0] < (2908065.0, 5815581.0] <
#                                             (5815581.0, 8723097.0] < (8723097.0, 11630613.0] < ... <
#                                             (17445645.0, 20353161.0] < (20353161.0, 23260677.0] <
#                                             (23260677.0, 26168193.0] < (26168193.0, 29075709.0]]

# %%
'''
  Có gần 25.000 video từ 549 views - 999.774 views
  Có xấp xỉ 7.000 video từ 999.774 views - 1.998.999 views
  Có 3000 video từ 1.998.999 views - 2.998.224 views
  Có 2000 video từ 2.998.224 views - 3.997.449 views
  .......... tương tự
'''
df.groupby('Views_Cut')['views'].count().plot.bar()
plt.xticks(rotation=52)
plt.ylabel('observation count')
# Out:
# Text(0, 0.5, 'observation count')

# %%
df['likes'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
maxrange = int(np.ceil(max(df['likes'])))
minrange = int(np.floor(min(df['likes'])))
likesrange = maxrange - minrange
bins = 10
#Số cột tối đa để group by dữ liệu
binwidth = int(np.round(likesrange/bins))

# %%
print('max range is', maxrange)
print('min range is', minrange)
print('likes range is', likesrange)
print('bin width is', binwidth)
# Out:
# max range is 397715
# min range is 0
# likes range is 397715
# bin width is 39772

# %%
intervals = [ views for views in range(minrange, maxrange + binwidth, binwidth)]
intervals
# Out:
# [0,
#  39772,
#  79544,
#  119316,
#  159088,
#  198860,
#  238632,
#  278404,
#  318176,
#  357948,
#  397720]

# %%
binlabels = ["bin" + str(i) for i in range (1, int(len(intervals)))]
binlabels
# Out:
# ['bin1',
#  'bin2',
#  'bin3',
#  'bin4',
#  'bin5',
#  'bin6',
#  'bin7',
#  'bin8',
#  'bin9',
#  'bin10']

# %%
df['Likes_Cut'] = pd.cut(df['likes'], bins = intervals, labels = None, include_lowest=True)
df['Likes_Cut']
# Out:
# video_id
# 2kyS6SvSYSE      (39772.0, 79544.0]
# 1ZAPwfrtAFY     (79544.0, 119316.0]
# 5qpjK5DgCt4    (119316.0, 159088.0]
# puqaWrEC7tY       (-0.001, 39772.0]
# d380meD0W0M    (119316.0, 159088.0]
#                        ...
# _QWZvU7VCn8      (39772.0, 79544.0]
# 7UoP9ABJXGE      (39772.0, 79544.0]
# BZt0qjTWNhw       (-0.001, 39772.0]
# D6Oy4LfoqsU      (39772.0, 79544.0]
# oV0zkMe1K8s    (159088.0, 198860.0]
# Name: Likes_Cut, Length: 38467, dtype: category
# Categories (10, interval[float64, right]): [(-0.001, 39772.0] < (39772.0, 79544.0] <
#                                             (79544.0, 119316.0] < (119316.0, 159088.0] < ... <
#                                             (238632.0, 278404.0] < (278404.0, 318176.0] <
#                                             (318176.0, 357948.0] < (357948.0, 397720.0]]

# %%
df.groupby('Likes_Cut')['likes'].count().plot.bar()
plt.xticks(rotation=52)
plt.ylabel('observation count')
# Out:
# Text(0, 0.5, 'observation count')

# %%
df['dislikes'].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
maxrange = int(np.ceil(max(df['dislikes'])))
minrange = int(np.floor(min(df['dislikes'])))
dislikerange = maxrange - minrange
bins = 10
#Số cột tối đa để group by dữ liệu
binwidth = int(np.round(dislikerange/bins))

# %%
print('max range is', maxrange)
print('min range is', minrange)
print('dislikes range is', dislikerange)
print('bin width is', binwidth)
# Out:
# max range is 38675
# min range is 0
# dislikes range is 38675
# bin width is 3868

# %%
intervals = [ views for views in range(minrange, maxrange + binwidth, binwidth)]
intervals
# Out:
# [0, 3868, 7736, 11604, 15472, 19340, 23208, 27076, 30944, 34812, 38680]

# %%
binlabels = ["bin" + str(i) for i in range (1, int(len(intervals)))]
binlabels
# Out:
# ['bin1',
#  'bin2',
#  'bin3',
#  'bin4',
#  'bin5',
#  'bin6',
#  'bin7',
#  'bin8',
#  'bin9',
#  'bin10']

# %%
df['Dislikes_Cut'] = pd.cut(df['dislikes'], bins = intervals, labels = None, include_lowest=True)
df['Dislikes_Cut']
# Out:
# video_id
# 2kyS6SvSYSE    (-0.001, 3868.0]
# 1ZAPwfrtAFY    (3868.0, 7736.0]
# 5qpjK5DgCt4    (3868.0, 7736.0]
# puqaWrEC7tY    (-0.001, 3868.0]
# d380meD0W0M    (-0.001, 3868.0]
#                      ...
# _QWZvU7VCn8    (-0.001, 3868.0]
# 7UoP9ABJXGE    (-0.001, 3868.0]
# BZt0qjTWNhw    (-0.001, 3868.0]
# D6Oy4LfoqsU    (-0.001, 3868.0]
# oV0zkMe1K8s    (-0.001, 3868.0]
# Name: Dislikes_Cut, Length: 38467, dtype: category
# Categories (10, interval[float64, right]): [(-0.001, 3868.0] < (3868.0, 7736.0] < (7736.0, 11604.0] <
#                                             (11604.0, 15472.0] ... (23208.0, 27076.0] <
#                                             (27076.0, 30944.0] < (30944.0, 34812.0] <
#                                             (34812.0, 38680.0]]

# %%
df.groupby('Dislikes_Cut')['dislikes'].count().plot.bar()
plt.xticks(rotation=52)
plt.ylabel('observation count')
# Out:
# Text(0, 0.5, 'observation count')

# %%
df = df.drop('Dislikes_Cut', axis='columns')
df = df.drop('Views_Cut', axis='columns')
df = df.drop('Likes_Cut', axis='columns')

# %%
df.head(50)
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# gHZ1Qz0KiKM      17.14.11                              2 Weeks with iPhone X
# 39idVpFF7NQ      17.14.11          Roy Moore & Jeff Sessions Cold Open - SNL
# nc99ccSXST0      17.14.11                5 Ice Cream Gadgets put to the Test
# jr9QtXwC9vc      17.14.11  The Greatest Showman | Official Trailer 2 [HD]...
# TUmyygCMMGA      17.14.11  Why the rise of the robots won’t mean the end ...
# 9wRQljFNDW8      17.14.11  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# ...

# %% [markdown]
# # **Giá trị trung bình**

# %%
df.mean(axis=0, numeric_only=True)
# Out:
# category_id      2.025443e+01
# views            1.392780e+06
# likes            4.096883e+04
# dislikes         1.703419e+03
# comment_count    4.653284e+03
# dtype: float64

# %% [markdown]
# # **Giá trị trung vị**

# %%
df.median(axis=0, numeric_only=True)
# Out:
# category_id          24.0
# views            629429.0
# likes             16667.0
# dislikes            585.0
# comment_count      1713.0
# dtype: float64

# %% [markdown]
# # **Độ lệch chuẩn**

# %%
df.std(axis=0, numeric_only=True)
# Out:
# category_id      7.508976e+00
# views            2.271627e+06
# likes            6.145914e+04
# dislikes         3.384368e+03
# comment_count    9.237984e+03
# dtype: float64

# %% [markdown]
# # **Phân vị**

# %%
df.describe()
# Out:
#         category_id         views          likes      dislikes  comment_count
# count  38467.000000  3.846700e+04   38467.000000  38467.000000   38467.000000
# mean      20.254426  1.392780e+06   40968.834066   1703.418853    4653.284088
# std        7.508976  2.271627e+06   61459.138381   3384.368136    9237.984289
# min        1.000000  5.490000e+02       0.000000      0.000000       0.000000
# 25%       17.000000  2.326080e+05    5223.500000    192.000000     587.000000
# 50%       24.000000  6.294290e+05   16667.000000    585.000000    1713.000000
# 75%       25.000000  1.565474e+06   46971.000000   1635.000000    4833.500000
# max       43.000000  2.907571e+07  397715.000000  38675.000000  203884.000000

# %% [markdown]
# # **Xem xét phân bố của từng biến trong dữ liệu bằng cách sử dụng histogram, box plot, kernel density plot.**

# %%
fig = px.histogram(df,x="views", nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x="likes", nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df,x="dislikes" , nbins = 20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, y='views')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, y='likes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(df, y='dislikes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Kernel density plot**

# %%
df.likes.plot.density(color='red')
plt.title('Density Plot for Likes')
plt.show()

# %%
df.dislikes.plot.density(color='red')
plt.title('Density Plot for Dislikes')
plt.show()

# %%
df.views.plot.density(color='red')
plt.title('Density Plot for Views')
plt.show()

# %% [markdown]
# # **Độ tương quan**

# %%
correlationMatrix  = df[["views","likes","dislikes"]].corr()
print(correlationMatrix)
# Out:
#              views    likes  dislikes
# views     1.000000  0.70437  0.627408
# likes     0.704370  1.00000  0.542010
# dislikes  0.627408  0.54201  1.000000

# %%
#Heatmap
seaborn.heatmap(correlationMatrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Time series analysis**

# %%
time_series = df.groupby(["trending_date"])["trending_date"].count()
time_series = pd.DataFrame({"Trending Date": time_series.index, "Count": time_series.values})
time_series.head(10)
# Out:
#   Trending Date  Count
# 0      17.01.12    192
# 1      17.02.12    190
# 2      17.03.12    192
# 3      17.04.12    193
# 4      17.05.12    192
# 5      17.06.12    190
# 6      17.07.12    189
# 7      17.08.12    189
# 8      17.09.12    189
# 9      17.10.12    189

# %%
plt.figure(figsize=(20,10))
plt.plot(time_series['Trending Date'],time_series["Count"], color='tab:red')
plt.gca().set(title="Time Series Each Trending Date", xlabel="Ngày lên Trending", ylabel="Số lần")
plt.xticks(rotation=90, ha='right', fontsize=5)
plt.show()

# %% [markdown]
# #Linear Regression

# %%
plt.scatter(df["views"], df["dislikes"], 1)

# %%
plt.scatter(df["views"], df["likes"], 1)

# %%
plt.scatter(df["dislikes"], df["likes"], 1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df_test = df.sample(frac=(8/100), random_state=0)

features = ['likes', 'dislikes']
target = 'views'  # 'views' là thuộc tính mục tiêu để dự đoán (số lượt xem)

X = df_test[features].values
y = df_test[target].values
print(X)
print(y)
print(len(X))

# df_test.index[df_test['views'] == 278273].tolist()
# print(df_test.loc[['HCIqTAFRkko']])
# Out:
# [[286477   7968]
#  [ 44054    768]
#  [ 34925   1491]
#  ...
#  [ 96767   4413]
#  [ 48032   1006]
#  [ 83372   1107]]
# [6773278  693389 1520030 ... 3105892 1606635 1727422]
# 3077

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
print(X_test[:5])
print(y_test[:5])
# Out:
# [[   895     39]
#  [  3844    112]
#  [117315   1351]
#  [ 23638    240]
#  [ 10018   1732]]
# [  36787  278273 1848703  352080 1238086]

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_test = y_train

# %%
y_pred = clf.predict(X_train)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(accuracy)
print(precision)
print(recall)
print(f1)
# Out:
# 0.994148244473342
# 0.9926156418354077
# 0.994148244473342
# 0.9930104031209362
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
indices = np.arange(len(y_test))

# Vẽ biểu đồ so sánh dự đoán và thực tế
plt.figure(figsize=(8, 4))
plt.bar(indices, y_test, color='blue', alpha=0.5, label='Thực tế')
plt.bar(indices, y_pred, color='red', alpha=0.5, label='Dự đoán')
plt.xticks(indices)
plt.xlabel('Mẫu')
plt.ylabel('Nhãn')
plt.legend()
plt.title('So sánh dự đoán và thực tế')
plt.show()

# %% [markdown]
# # K-means Clustering

# %%
features = ["views", "likes", "dislikes"]
data = df[features].copy()

# %%
data
# Out:
#                views   likes  dislikes
# video_id
# 2kyS6SvSYSE   748374   57527      2966
# 1ZAPwfrtAFY  2418783   97185      6146
# 5qpjK5DgCt4  3191434  146033      5339
# puqaWrEC7tY   343168   10172       666
# d380meD0W0M  2095731  132235      1989
# ...              ...     ...       ...
# _QWZvU7VCn8  5564576   46351      2295
# 7UoP9ABJXGE  5534278   45128      1591
# BZt0qjTWNhw  1685609   38160      1385
# D6Oy4LfoqsU  1066451   48068      1032
# oV0zkMe1K8s  5660813  192957      2846
#
# [38467 rows x 3 columns]

# %%
data = ((data - data.min()) / (data.max() - data.min())) * 9 + 1

# %%
data.describe()
# Out:
#               views         likes      dislikes
# count  38467.000000  38467.000000  38467.000000
# mean       1.430955      1.927095      1.396400
# std        0.703165      1.390775      0.787571
# min        1.000000      1.000000      1.000000
# 25%        1.071832      1.118204      1.044680
# 50%        1.194665      1.377162      1.136134
# 75%        1.484411      2.062919      1.380478
# max       10.000000     10.000000     10.000000

# %%
data.head()
# Out:
#                 views     likes  dislikes
# video_id
# 2kyS6SvSYSE  1.231484  2.301794  1.690213
# 1ZAPwfrtAFY  1.748546  3.199226  2.430226
# 5qpjK5DgCt4  1.987715  4.304620  2.242431
# puqaWrEC7tY  1.106055  1.230185  1.154984
# d380meD0W0M  1.648548  3.992381  1.462857

# %%
def random_centroids(data, k):
    centroids = []
    for i in range(k):
        centroid = data.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids, axis=1)

# %%
centroids = random_centroids(data, 5)

# %%
centroids
# Out:
#                  0         1         2         3         4
# views     1.137285  1.074970  1.229538  1.691184  1.140965
# likes     1.608569  1.043674  3.275283  1.054016  1.011858
# dislikes  1.012334  1.039095  1.145443  1.043982  2.282922

# %%
def get_labels(data, centroids):
    distances = centroids.apply(lambda x: np.sqrt(((data - x) ** 2).sum(axis=1)))
    return distances.idxmin(axis=1)

# %%
labels = get_labels(data, centroids)

# %%
labels.value_counts()
# Out:
# 1    16753
# 0    11320
# 2     7135
# 4     1669
# 3     1590
# dtype: int64

# %%
def new_centroids(data, labels, k):
    centroids = data.groupby(labels).apply(lambda x: np.exp(np.log(x).mean())).T
    return centroids

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
def plot_clusters(data, labels, centroids, iteration):
    pca = PCA(n_components=2)
    data_2d = pca.fit_transform(data)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.title(f'Iteration {iteration}')
    plt.scatter(x=data_2d[:,0], y=data_2d[:,1], c=labels, s=1)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1], s=10, marker='x', color = 'r')
    plt.show()

# %%
max_iterations = 100
centroid_count = 5

centroids = random_centroids(data, centroid_count)
old_centroids = pd.DataFrame()
iteration = 1

while iteration < max_iterations and not centroids.equals(old_centroids):
    old_centroids = centroids
    
    labels = get_labels(data, centroids)
    centroids = new_centroids(data, labels, centroid_count)
    plot_clusters(data, labels, centroids, iteration)
    iteration += 1

# %%
centroids
# Out:
#                  0         1         2         3         4
# views     1.674762  1.302966  1.086149  1.950629  3.294388
# likes     2.298058  1.577104  1.129116  4.075616  6.457339
# dislikes  1.629502  1.245760  1.068107  1.782034  3.015319

# %%
df[labels == 3][["title"] + features]
# Out:
#                                                          title    views  \
# video_id
# 1ZAPwfrtAFY  The Trump Presidency: Last Week Tonight with J...  2418783
# 5qpjK5DgCt4  Racist Superman | Rudy Mancuso, King Bach & Le...  3191434
# d380meD0W0M                           I Dare You: GOING BALD!?  2095731
# 5E4ZBSInqUU         Marshmello - Blocks (Official Music Video)   687582
# ujyTQNNjjDU                 G-Eazy - The Plan (Official Video)  2642930
# ...                                                        ...      ...
# 99t4EBwIAt8  Shawn Mendes Answers the Web's Most Searched Q...  2310794
# SQsPvrev_bQ                                                435  2252933
# oLDbO545aKQ  Terrible Magicians | Rudy Mancuso & Juanpa Zurita  3825440
# Xr2rgT9uEnA              LIE DETECTOR TEST WITH MY GIRLFRIEND!  3229540
# oV0zkMe1K8s                How Black Panther Should Have Ended  5660813
#
#               likes  dislikes
# video_id
# 1ZAPwfrtAFY   97185      6146
# ...

# %%
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score as sil_score
from sklearn.metrics import adjusted_rand_score as rand_index

def compute_sse(data, labels, centroids):
    distances = pairwise_distances(data, centroids[labels])
    sse = np.sum(distances ** 2)
    return sse

def compute_silhouette_score(data, labels):
    silhouette = sil_score(data, labels)
    return silhouette

def compute_rand_index(true_labels, labels):
    rand = rand_index(true_labels, labels)
    return rand
